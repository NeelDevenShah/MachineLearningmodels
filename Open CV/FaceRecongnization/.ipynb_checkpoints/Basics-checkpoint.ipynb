# %% [markdown]
# **Here, for making the face rocegonization we have used folllowing libraries, And this is the basic project, And the other .ipynb is the attendence project
# 1. open cv
# 2. numpy
# 3. cmake
# 4. dlib
# 5. face_recognition

# %%
import cv2
import numpy as np
import face_recognition

imgElon = face_recognition.load_image_file('imageData/elonMusk.jpeg')
imgElon = cv2.cvtColor(imgElon, cv2.COLOR_BGR2RGB)
imgTest = face_recognition.load_image_file('imageData/elontest.jpg') # For True
# imgTest = face_recognition.load_image_file('imageData/billTest.jpeg')  # For False
imgTest = cv2.cvtColor(imgTest, cv2.COLOR_BGR2RGB)

faceLoc = face_recognition.face_locations(imgElon)[0]
# The return value of the face_recognition.face_locations function will be in format (top, right, bottom, left)
# Hence, we have right (3, 0), (1, 2)
encodeElon = face_recognition.face_encodings(imgElon)[0]
cv2.rectangle(imgElon, (faceLoc[3], faceLoc[0]), (faceLoc[1], faceLoc[2]), (255, 0, 255), 2)

faceLocTest = face_recognition.face_locations(imgTest)[0]
encodeTest = face_recognition.face_encodings(imgTest)[0]
cv2.rectangle(imgTest, (faceLocTest[3], faceLocTest[0]), (faceLocTest[1], faceLocTest[2]), (255, 0, 255), 2)

results = face_recognition.compare_faces([encodeElon], encodeTest)
faceDis = face_recognition.face_distance([encodeElon], encodeTest)
print(results, faceDis)
cv2.putText(imgTest, f'{results} {round(faceDis[0], 2)}', (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2)

cv2.imshow('Elon Musk', imgElon)
cv2.imshow('Elon Test', imgTest)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [True] [0.39984328]
# QObject::moveToThread: Current thread (0x8e71840) is not the object's thread (0xb6a9d90).
# Cannot move to target thread (0x8e71840)
#
# QObject::moveToThread: Current thread (0x8e71840) is not the object's thread (0xb6a9d90).
# Cannot move to target thread (0x8e71840)
#
# QObject::moveToThread: Current thread (0x8e71840) is not the object's thread (0xb6a9d90).
# Cannot move to target thread (0x8e71840)
#
# QObject::moveToThread: Current thread (0x8e71840) is not the object's thread (0xb6a9d90).
# Cannot move to target thread (0x8e71840)
#
# QObject::moveToThread: Current thread (0x8e71840) is not the object's thread (0xb6a9d90).
# Cannot move to target thread (0x8e71840)
#
# QObject::moveToThread: Current thread (0x8e71840) is not the object's thread (0xb6a9d90).
# Cannot move to target thread (0x8e71840)
#
# QObject::moveToThread: Current thread (0x8e71840) is not the object's thread (0xb6a9d90).
# Cannot move to target thread (0x8e71840)
#
# ...

# %% [markdown]
# -->Less the distance more the sutaible image is
